# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from pathlib import Path as Path
import sqlite3
import os

# %%
spark_version ='spark-3.0.3'
os.environ['SPARK_VERSION']=spark_version
 #Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http:apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7tgz
# !tar xf $SPARK_VERSION-bin-hapoop2.7tgz!pip install -q findspark
# !pip install -q findspark

#Set Environment Variables
os.environ['JAVA_HOME']= "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"]=f"/content/{spark_version}-bin-hadoop2,7"

#start a Spark Session
import findspark
findspark.init()
# Out:
# zsh:1: command not found: apt-get
# zsh:1: command not found: apt-get
# zsh:1: command not found: wget
# tar: Error opening archive: Failed to open 'spark-3.0.3-bin-hapoop2.7tgz!pip'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     158         try:
# --> 159             py4j = glob(os.path.join(spark_python, "lib", "py4j-*.zip"))[0]
#     160         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /var/folders/v6/lm_zzc0x73g0qw5nj3xn0ydw0000gn/T/ipykernel_62645/1753297967.py in <module>
#      14 #start a Spark Session
#      15 import findspark
# ---> 16 findspark.init()
#
# /opt/anaconda3/lib/python3.9/site-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     159             py4j = glob(os.path.join(spark_python, "lib", "py4j-*.zip"))[0]
#     160         except IndexError:
# --> 161             raise Exception(
#     162                 "Unable to find py4j in {}, your SPARK_HOME may not be configured correctly".format(
#     163                     spark_python
#
# Exception: Unable to find py4j in /content/spark-3.0.3-bin-hadoop2,7/python, your SPARK_HOME may not be configured correctly

# %%
#pull in data from which analysis is built
edx_course_descriptions = pd.read_csv('edx_courses.csv')
edx_course_descriptions.tail(3)
# Out:
#                                                   title  \
# 2703  Computational Neuroscience: Neuronal Dynamics ...
# 2704  Cities and the Challenge of Sustainable Develo...
# 2705                      MathTrackX: Special Functions
#
#                                                 summary n_enrolled  \
# 2703  This course explains the mathematical and comp...     11,246
# 2704  What is a sustainable city? Learn the basics h...      8,775
# 2705  Understand trigonometric, exponential and loga...        NaN
#
#                   course_type                               institution  \
# 2703  Self-paced on your time  École polytechnique fédérale de Lausanne
# 2704  Self-paced on your time                               SDG Academy
# 2705  Self-paced on your time                    University of Adelaide
#
#            instructors         Level                  subject language  \
# 2703  Wulfram Gerstner      Advanced  Biology & Life Sciences  English
# 2704  Jeffrey D. Sachs  Introductory    Environmental Studies  English
# 2705   Dr David Butler  Introductory                     Math  English
#
#      subtitles  ...                                         price  \
# 2703   English  ...  FREE-Add a Verified Certificate for $139 USD
# 2704   English  ...   FREE-Add a Verified Certificate for $25 USD
# 2705   English  ...   FREE-Add a Verified Certificate for $79 USD
#
#                                      course_description  \
# 2703  What happens in your brain when you make a dec...
# 2704  According to the United Nations, urbanization ...
# 2705  This course is part two of the MathTrackX XSer...
#
#                                         course_syllabus  \
# 2703  Textbook: Neuronal Dynamics - from single neur...
# 2704  Module 1: Introduction to the SDGsProfessor Je...
# 2705                                                NaN
#
#                                              course_url Unnamed: 16  \
# 2703  https://www.edx.org/course/computational-neuro...         NaN
# 2704  https://www.edx.org/course/cities-and-the-chal...         NaN
# 2705  https://www.edx.org/course/mathtrackx-special-...         NaN
#
#      Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 2703         NaN         NaN         NaN         NaN         NaN
# 2704         NaN         NaN         NaN         NaN         NaN
# 2705         NaN         NaN         NaN         NaN         NaN
#
# [3 rows x 22 columns]

# %%
#Snap shot of data set
edx_user_data = pd.read_csv('big_student_clear_third_version.csv')
edx_user_data.head(3)
# Out:
#    Unnamed: 0 institute course_id  year semester       userid_DI  viewed  \
# 0           4  HarvardX    PH207x  2012     Fall  MHxPC130313697       0
# 1           6  HarvardX    PH207x  2012     Fall  MHxPC130237753       1
# 2           7  HarvardX     CS50x  2012   Summer  MHxPC130202970       1
#
#    explored  certified final_cc_cname_DI  ... grade start_time_DI  \
# 0         0          0             India  ...   0.0    2012-07-24
# 1         0          0     United States  ...   0.0    2012-07-24
# 2         0          0     United States  ...   0.0    2012-07-24
#
#    last_event_DI nevents ndays_act  nplay_video  nchapters  nforum_posts  \
# 0     2013-07-27       6         3       197757          0             0
# 1     2012-12-24     107         8            7          2             0
# 2     2013-03-28       8         1       197757          1             0
#
#    incomplete_flag  age
# 0                0   23
# 1                0   19
# 2                0   24
#
# [3 rows x 22 columns]

# %%
#types of Columns in data frame
edx_course_descriptions.dtypes
# Out:
# title                 object
# summary               object
# n_enrolled            object
# course_type           object
# institution           object
# instructors           object
# Level                 object
# subject               object
# language              object
# subtitles             object
# course_effort         object
# course_length         object
# price                 object
# course_description    object
# course_syllabus       object
# course_url            object
# Unnamed: 16           object
# Unnamed: 17           object
# Unnamed: 18           object
# Unnamed: 19           object
# Unnamed: 20           object
# Unnamed: 21           object
# dtype: object

# %%
#edit columns to clean and transform to string data and replace commas
edx_course_descriptions['n_enrolled'] = edx_course_descriptions['n_enrolled'].astype(str).str.replace(',', '')
edx_course_descriptions['price'] = edx_course_descriptions['price'].astype(str).str.replace('FREE-Add a Verified Certificate for', '')
edx_course_descriptions['price'] = edx_course_descriptions['price'].astype(str).str.replace('$', '')
edx_course_descriptions['price'] = edx_course_descriptions['price'].astype(str).str.replace('USD', '')
edx_course_descriptions['course_length'] = edx_course_descriptions['course_length'].astype(str).str.replace('Weeks', '')
# Out:
# /var/folders/v6/lm_zzc0x73g0qw5nj3xn0ydw0000gn/T/ipykernel_45275/1770424892.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   edx_course_descriptions['price'] = edx_course_descriptions['price'].astype(str).str.replace('$', '')

# %%
edx_course_descriptions['n_enrolled'] = edx_course_descriptions['n_enrolled'].fillna(0)

# %%
edx_course_descriptions['n_enrolled'] = edx_course_descriptions['n_enrolled'].astype(int)

# %%
edx_course_descriptions['price'] = edx_course_descriptions['price'].astype(float)

# %%
edx_course_descriptions['course_length'] = edx_course_descriptions['course_length'].astype(int)

# %%
#calculate number of missing values
edx_course_descriptions.isna().sum()
# Out:
# title                    0
# summary               1191
# n_enrolled               0
# course_type           1558
# institution           1631
# instructors           1671
# Level                 1691
# subject               1699
# language              1706
# subtitles             1720
# course_effort         1718
# course_length            0
# price                    0
# course_description    1766
# course_syllabus       2303
# course_url            1925
# Unnamed: 16           2703
# Unnamed: 17           2704
# Unnamed: 18           2704
# Unnamed: 19           2704
# Unnamed: 20           2705
# Unnamed: 21           2705
# dtype: int64

# %%
edx_course_descriptions['summary'] = edx_course_descriptions['summary'].fillna('Unlisted')

# %%
edx_course_descriptions['instructors'] = edx_course_descriptions['instructors'].fillna('Unlisted')

# %%
edx_course_descriptions['subtitles'] = edx_course_descriptions['subtitles'].fillna('English')

# %%
edx_course_descriptions['course_description'] = edx_course_descriptions['course_description'].fillna('Unlisted')

# %%
edx_course_descriptions['course_syllabus'] = edx_course_descriptions['course_syllabus'].fillna('Unlisted')

# %%
#effectivly checking the compleness of data.
edx_course_descriptions.tail(3)
# Out:
#                                                   title  \
# 2703  Computational Neuroscience: Neuronal Dynamics ...
# 2704  Cities and the Challenge of Sustainable Develo...
# 2705                      MathTrackX: Special Functions
#
#                                                 summary  n_enrolled  \
# 2703  This course explains the mathematical and comp...       11246
# 2704  What is a sustainable city? Learn the basics h...        8775
# 2705  Understand trigonometric, exponential and loga...           0
#
#                   course_type                               institution  \
# 2703  Self-paced on your time  École polytechnique fédérale de Lausanne
# 2704  Self-paced on your time                               SDG Academy
# 2705  Self-paced on your time                    University of Adelaide
#
#            instructors         Level                  subject language  \
# 2703  Wulfram Gerstner      Advanced  Biology & Life Sciences  English
# 2704  Jeffrey D. Sachs  Introductory    Environmental Studies  English
# 2705   Dr David Butler  Introductory                     Math  English
#
#      subtitles  ...  price                                 course_description  \
# 2703   English  ...  139.0  What happens in your brain when you make a dec...
# 2704   English  ...   25.0  According to the United Nations, urbanization ...
# 2705   English  ...   79.0  This course is part two of the MathTrackX XSer...
#
#                                         course_syllabus  \
# 2703  Textbook: Neuronal Dynamics - from single neur...
# 2704  Module 1: Introduction to the SDGsProfessor Je...
# 2705                                           Unlisted
#
#                                              course_url Unnamed: 16  \
# 2703  https://www.edx.org/course/computational-neuro...         NaN
# 2704  https://www.edx.org/course/cities-and-the-chal...         NaN
# 2705  https://www.edx.org/course/mathtrackx-special-...         NaN
#
#      Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 2703         NaN         NaN         NaN         NaN         NaN
# 2704         NaN         NaN         NaN         NaN         NaN
# 2705         NaN         NaN         NaN         NaN         NaN
#
# [3 rows x 22 columns]

# %%
#Delete column "Course_url"
del edx_course_descriptions['course_url']

# %%
edx_course_descriptions.tail(3)
# Out:
#                                                   title  \
# 2703  Computational Neuroscience: Neuronal Dynamics ...
# 2704  Cities and the Challenge of Sustainable Develo...
# 2705                      MathTrackX: Special Functions
#
#                                                 summary  n_enrolled  \
# 2703  This course explains the mathematical and comp...       11246
# 2704  What is a sustainable city? Learn the basics h...        8775
# 2705  Understand trigonometric, exponential and loga...           0
#
#                   course_type                               institution  \
# 2703  Self-paced on your time  École polytechnique fédérale de Lausanne
# 2704  Self-paced on your time                               SDG Academy
# 2705  Self-paced on your time                    University of Adelaide
#
#            instructors         Level                  subject language  \
# 2703  Wulfram Gerstner      Advanced  Biology & Life Sciences  English
# 2704  Jeffrey D. Sachs  Introductory    Environmental Studies  English
# 2705   Dr David Butler  Introductory                     Math  English
#
#      subtitles  ... course_length  price  \
# 2703   English  ...             6  139.0
# 2704   English  ...             1   25.0
# 2705   English  ...             4   79.0
#
#                                      course_description  \
# 2703  What happens in your brain when you make a dec...
# 2704  According to the United Nations, urbanization ...
# 2705  This course is part two of the MathTrackX XSer...
#
#                                         course_syllabus Unnamed: 16  \
# 2703  Textbook: Neuronal Dynamics - from single neur...         NaN
# 2704  Module 1: Introduction to the SDGsProfessor Je...         NaN
# 2705                                           Unlisted         NaN
#
#      Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 2703         NaN         NaN         NaN         NaN         NaN
# 2704         NaN         NaN         NaN         NaN         NaN
# 2705         NaN         NaN         NaN         NaN         NaN
#
# [3 rows x 21 columns]

# %%
edx_course_descriptions['Level'] = edx_course_descriptions['Level'].astype('category')

# %%
edx_course_descriptions['Level'] = edx_course_descriptions['Level'].cat.codes

# %%
edx_course_descriptions['course_type'] = edx_course_descriptions['course_type'].astype('category')
edx_course_descriptions['course_type'] = edx_course_descriptions['course_type'].cat.codes

# %%
edx_course_descriptions.dtypes
# Out:
# title                  object
# summary                object
# n_enrolled              int64
# course_type             int16
# institution            object
# instructors            object
# Level                    int8
# subject                object
# language               object
# subtitles              object
# course_effort          object
# course_length           int64
# price                 float64
# course_description     object
# course_syllabus        object
# Unnamed: 16            object
# Unnamed: 17            object
# Unnamed: 18            object
# Unnamed: 19            object
# Unnamed: 20            object
# Unnamed: 21            object
# dtype: object

# %%
# quick check of columns in data set.
print(edx_user_data.columns)
# Out:
# Index(['Unnamed: 0', 'institute', 'course_id', 'year', 'semester', 'userid_DI',
#        'viewed', 'explored', 'certified', 'final_cc_cname_DI', 'LoE_DI',
#        'gender', 'grade', 'start_time_DI', 'last_event_DI', 'nevents',
#        'ndays_act', 'nplay_video', 'nchapters', 'nforum_posts',
#        'incomplete_flag', 'age'],
#       dtype='object')

# %%
# Measure the depth and breadth of data set (count ,mean,std,min etc)
edx_course_descriptions.describe()
# Out:
#          n_enrolled  course_type        Level  course_length        price
# count  2.706000e+03  2706.000000  2706.000000    2706.000000  2706.000000
# mean   1.682582e+04    61.130081    13.168884       2.407982    36.129290
# std    7.131969e+04    75.277724    18.478982       3.726985    63.773775
# min    0.000000e+00    -1.000000    -1.000000       0.000000     0.000000
# 25%    0.000000e+00    -1.000000    -1.000000       0.000000     0.000000
# 50%    0.000000e+00    -1.000000    -1.000000       0.000000     0.000000
# 75%    1.049700e+04   156.000000    37.000000       5.000000    49.000000
# max    2.442271e+06   175.000000    44.000000      18.000000   450.000000

# %%
#Count Descriptions of "Subjects"
edx_course_descriptions['subject'].value_counts()
# Out:
# Computer Science                                                                                                                                                                   166
# Business & Management                                                                                                                                                              164
# Data Analysis & Statistics                                                                                                                                                          72
# Humanities                                                                                                                                                                          64
# Engineering                                                                                                                                                                         58
#                                                                                                                                                                                   ...
#  and the interplay of actors that constitute health not only in local communities but also on a global scale. In this course                                                         1
#  estrellas                                                                                                                                                                           1
#  we'll introduce some strategies to make your pronunciation clearer. In this module                                                                                                  1
#  etc. La perspectiva de operaciones                                                                                                                                                  1
#  originality and methods. Sceneries in the course videos are delightful. Rhythm and the mode of voice is a feast for the eyes as is music. You are sincerely invited to join us      1
# Name: subject, Length: 64, dtype: int64

# %%
edx_course_description_csv = edx_course_descriptions.to_csv("edx_course_description_for_bq.csv")

# %%
#create a SQl file path
Path('edx_course_descriptions.db').touch()
edx_conn = sqlite3.connect('edx_course_descriptions.db')
edx_cursor = edx_conn.cursor()

# %%
# to SQL Method to append data to Table for SQLite
edx_course_descriptions.to_sql('edx_course_descriptions', edx_conn, if_exists='append', index=False)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# read data table to return results to view columns of table
edx_description_init_query = pd.read_sql(''' SELECT * FROM edx_course_descriptions ''', edx_conn)
edx_description_init_query
# Out:
#                                                   title  \
# 0                                   How to Learn Online
# 1     Programming for Everybody (Getting Started wit...
# 2               CS50's Introduction to Computer Science
# 3                                    The Analytics Edge
# 4     Marketing Analytics: Marketing Measurement Str...
# ...                                                 ...
# 2701       感受美、提炼美、表现美的过程体验。您将获得艺术创作思维的拓展与适合自己的图案创作方法。"
# 2702                                   Come and join us
# 2703  Computational Neuroscience: Neuronal Dynamics ...
# 2704  Cities and the Challenge of Sustainable Develo...
# 2705                      MathTrackX: Special Functions
#
#                                                 summary  n_enrolled  \
# 0     Learn essential strategies for successful onli...      124980
# 1     This course is a "no prerequisite" introductio...      293864
# 2     An introduction to the intellectual enterprise...     2442271
# 3     Through inspiring examples and stories, discov...      129555
# 4        This course is part of a MicroMasters® Program       81140
# ...                                                 ...         ...
# 2701                                           Unlisted           0
# 2702                                    expandyour mind           0
# 2703  This course explains the mathematical and comp...       11246
# 2704  What is a sustainable city? Learn the basics h...        8775
# 2705  Understand trigonometric, exponential and loga...           0
#
#       course_type                               institution  \
# 0             156                                       edX
# 1             156                The University of Michigan
# 2             156                        Harvard University
# 3             155     Massachusetts Institute of Technology
# 4             156        University of California, Berkeley
# ...           ...                                       ...
# 2701          157                                Yuehua Nie
# 2702          137                                   history
# 2703          156  École polytechnique fédérale de Lausanne
# 2704          156                               SDG Academy
# 2705          156                    University of Adelaide
#
#                                             instructors  Level  \
# 0               Nina Huntemann-Robyn Belair-Ben Piscopo     38
# 1                                     Charles Severance     38
# 2                    David J. Malan-Doug Lloyd-Brian Yu     38
# 3     Dimitris Bertsimas-Allison O'Hair-John Silberh...     37
# 4                                        Stephan Sorger     38
# ...                                                 ...    ...
# 2701                                       Introductory     36
# 2702                                            culture      6
# 2703                                   Wulfram Gerstner     35
# 2704                                   Jeffrey D. Sachs     38
# 2705                                    Dr David Butler     38
#
#                                                 subject  \
# 0                          Education & Teacher Training
# 1                                      Computer Science
# 2                                      Computer Science
# 3                            Data Analysis & Statistics
# 4                                      Computer Science
# ...                                                 ...
# 2701                                                 中文
# 2702   originality and methods. Sceneries in the cou...
# 2703                            Biology & Life Sciences
# 2704                              Environmental Studies
# 2705                                               Math
#
#                                                language           subtitles  \
# 0                                               English             English
# 1                                               English             English
# 2                                               English             English
# 3                                               English             English
# 4                                               English             English
# ...                                                 ...                 ...
# 2701                                        English, 中文  3–5 hours per week
# 2702   exploring a journey of aesthetics. 你想成为一名原创设计...             English
# 2703                                            English             English
# 2704                                            English             English
# 2705                                            English             English
#
#       ... course_length  price  \
# 0     ...             2   49.0
# 1     ...             7   49.0
# 2     ...            12   90.0
# 3     ...            13  199.0
# 4     ...             4  249.0
# ...   ...           ...    ...
# 2701  ...             0    0.0
# 2702  ...             0    0.0
# 2703  ...             6  139.0
# 2704  ...             1   25.0
# 2705  ...             4   79.0
#
#                                      course_description  \
# 0     Designed for those who are new to elearning, t...
# 1     This course aims to teach everyone the basics ...
# 2     This is CS50x , Harvard University's introduct...
# 3     In the last decade, the amount of data availab...
# 4     Begin your journey in a new career in marketin...
# ...                                                 ...
# 2701                                           Unlisted
# 2702                                           Unlisted
# 2703  What happens in your brain when you make a dec...
# 2704  According to the United Nations, urbanization ...
# 2705  This course is part two of the MathTrackX XSer...
#
#                                         course_syllabus Unnamed: 16  \
# 0     Welcome - We start with opportunities to meet ...        None
# 1                                              Unlisted        None
# 2                                              Unlisted        None
# 3                                              Unlisted        None
# 4                                              Unlisted        None
# ...                                                 ...         ...
# 2701                                           Unlisted        None
# 2702                                           Unlisted        None
# 2703  Textbook: Neuronal Dynamics - from single neur...        None
# 2704  Module 1: Introduction to the SDGsProfessor Je...        None
# 2705                                           Unlisted        None
#
#      Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0           None        None        None        None        None
# 1           None        None        None        None        None
# 2           None        None        None        None        None
# 3           None        None        None        None        None
# 4           None        None        None        None        None
# ...          ...         ...         ...         ...         ...
# 2701        None        None        None        None        None
# 2702        None        None        None        None        None
# 2703        None        None        None        None        None
# 2704        None        None        None        None        None
# 2705        None        None        None        None        None
#
# [2706 rows x 21 columns]

# %%
#query data, with filtering of rows,ordered by price Limit of 15
data_analysis_query = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution 
                                      FROM edx_course_descriptions
                                      WHERE subject == 'Data Analysis & Statistics'
                                      ORDER BY price DESC LIMIT 15 ''', edx_conn)
data_analysis_query
# Out:
#                                                 title  price  \
# 0                             Python for Data Science  350.0
# 1   Probability and Statistics in Data Science usi...  350.0
# 2                       Machine Learning Fundamentals  350.0
# 3   Probability - The Science of Uncertainty and Data  300.0
# 4                                    Statistics and R  249.0
# 5     Data Analytics and Visualization in Health Care  249.0
# 6                                  The Analytics Edge  199.0
# 7   Data Science for Construction, Architecture an...  199.0
# 8   Probability and Statistics I:  A Gentle Introd...  199.0
# 9   Image Processing and Analysis for Life Scientists  199.0
# 10                             Big Data and Education  169.0
# 11                     High-Dimensional Data Analysis  149.0
# 12                       Introduction to Bioconductor  149.0
# 13  Statistical Inference and Modeling for High-th...  149.0
# 14                Case Studies in Functional Genomics  149.0
#
#            course_effort  n_enrolled                               institution
# 0    8–10 hours per week      266978   The University of California, San Diego
# 1   10–12 hours per week      106286   The University of California, San Diego
# 2    8–10 hours per week       82008   The University of California, San Diego
# 3   10–14 hours per week      205615     Massachusetts Institute of Technology
# 4     2–4 hours per week      314586                        Harvard University
# 5    8–10 hours per week        7304         Rochester Institute of Technology
# 6   10–15 hours per week      129555     Massachusetts Institute of Technology
# 7     4–6 hours per week       11113      The National University of Singapore
# 8    6–10 hours per week           0       The Georgia Institute of Technology
# 9     2–3 hours per week        8621  École polytechnique fédérale de Lausanne
# 10   6–12 hours per week       14909                University of Pennsylvania
# 11    2–4 hours per week       78443                        Harvard University
# 12    2–4 hours per week       36370                        Harvard University
# 13    2–4 hours per week       51590                        Harvard University
# 14    2–4 hours per week       26850                        Harvard University

# %%
#Barplot visualization with price in x asis and title in y axis
sns.barplot(x = 'price', y = 'title', data = data_analysis_query, color = 'blue', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='price', ylabel='title'>

# %%
sns.barplot(x = 'n_enrolled', y = 'title', data = data_analysis_query, color = 'blue', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='n_enrolled', ylabel='title'>

# %%
sns.barplot(x = 'price', y = 'n_enrolled', data = data_analysis_query, color = 'blue', edgecolor = 'black', ci=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='n_enrolled'>

# %%
data_analysis_query.mean()
# Out:
# /var/folders/v6/lm_zzc0x73g0qw5nj3xn0ydw0000gn/T/ipykernel_45275/2810120541.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_analysis_query.mean()
# price           227.266667
# n_enrolled    89348.533333
# dtype: float64

# %%
data_analysis_python = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution
                                       FROM edx_course_descriptions
                                       WHERE title LIKE '%Python'
                                       ORDER BY price DESC  ''', edx_conn)
data_analysis_python
# Out:
#                                                title  price  \
# 0  Probability and Statistics in Data Science usi...  350.0
# 1                                Analytics in Python  249.0
# 2  CS50's Introduction to Artificial Intelligence...  199.0
# 3   Data Science: Computational Thinking with Python  199.0
# 4                    Estructuras de Datos con Python   49.0
# 5  Advanced Algorithmics and Graph Theory with Py...   49.0
# 6                         Analyzing Data with Python   39.0
# 7                       Visualizing Data with Python   39.0
# 8  Objects and Classes Module 4 - Working with Da...    0.0
#
#           course_effort  n_enrolled                              institution
# 0  10–12 hours per week      106286  The University of California, San Diego
# 1   8–10 hours per week       82210                      Columbia University
# 2  10–30 hours per week      258006                       Harvard University
# 3    4–6 hours per week       78232       University of California, Berkeley
# 4    2–4 hours per week           0               The University of Michigan
# 5    2–4 hours per week       13502                                      IMT
# 6    2–4 hours per week       94079                                      IBM
# 7    2–4 hours per week       42101                                      IBM
# 8                  None           0                                     None

# %%
sns.barplot(x = 'price', y = 'n_enrolled', data = data_analysis_python, color = 'orange', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='n_enrolled'>

# %%
data_analysis_prog = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution
                                       FROM edx_course_descriptions
                                       WHERE title LIKE '%Programming'
                                       ORDER BY price DESC  ''', edx_conn)
data_analysis_prog
# Out:
#                                                title  price  \
# 0                Basics of Computing and Programming  200.0
# 1                        Object-Oriented Programming  149.0
# 2  Computing in Python I: Fundamentals and Proced...   99.0
# 3                    AI Chatbots without Programming   99.0
#
#          course_effort  n_enrolled                          institution
# 0   6–8 hours per week       37045                  New York University
# 1   6–8 hours per week       93633                            IITBombay
# 2  9–10 hours per week      141966  The Georgia Institute of Technology
# 3   2–4 hours per week       35440                                  IBM

# %%
data_analysis_stat = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution
                                     FROM edx_course_descriptions
                                     WHERE title LIKE '%Statistics'
                                     ORDER BY price DESC ''', edx_conn)
data_analysis_stat
# Out:
#                                              title  price  \
# 0                                    BioStatistics   79.0
# 1                           MathTrackX: Statistics   79.0
# 2  Compilation Basics for Macroeconomic Statistics   25.0
# 3                    Public Sector Debt Statistics   25.0
#
#          course_effort  n_enrolled                      institution
# 0  5–10 hours per week       14937                 Doane University
# 1   3–6 hours per week           0           University of Adelaide
# 2   3–6 hours per week        6570  The International Monetary Fund
# 3   6–8 hours per week           0  The International Monetary Fund

# %%
data_analysis_prob = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution
                                     FROM edx_course_descriptions
                                     WHERE title LIKE '%Probability' AND title NOT LIKE '%MathTrackX: Probability'
                                     ORDER BY price DESC ''', edx_conn)
data_analysis_prob
# Out:
#                                                title  price  \
# 0  Probability and Statistics I:  A Gentle Introd...  199.0
# 1                        Introduction to Probability   99.0
# 2                        Introduction to Probability   99.0
# 3                          Data Science: Probability   49.0
# 4  • Recall the concepts of independence and cond...    0.0
# 5  • Lesson 4 [OPTIONAL]: Calculus Bootcamp: Inte...    0.0
# 6  • Lesson 7: Counting Techniques: Combinations ...    0.0
#
#          course_effort  n_enrolled                          institution
# 0  6–10 hours per week           0  The Georgia Institute of Technology
# 1  5–10 hours per week       97291                   Harvard University
# 2  5–10 hours per week       97291                   Harvard University
# 3   1–2 hours per week      135859                   Harvard University
# 4                 None           0                                 None
# 5                 None           0                                 None
# 6                 None           0                                 None

# %%
comp_sci_query = pd.read_sql(''' SELECT title, price, course_effort, n_enrolled, institution
                                 FROM edx_course_descriptions WHERE subject == 'Computer Science'
                                 ORDER BY price DESC LIMIT 15 ''', edx_conn)
comp_sci_query
# Out:
#                                                 title  price  \
# 0                  Information Technology Foundations  399.6
# 1   Driving Digital Innovation through Experimenta...  399.0
# 2   Machine Learning with Python: from Linear Mode...  300.0
# 3                    Network and Security Foundations  299.7
# 4               Scripting and Programming Foundations  299.7
# 5                     Cloud Computing for Enterprises  299.0
# 6   Marketing Analytics: Marketing Measurement Str...  249.0
# 7   Marketing Analytics: Competitive Analysis and ...  249.0
# 8                        Artificial Intelligence (AI)  249.0
# 9                                    Machine Learning  249.0
# 10  Marketing Analytics: Products, Distribution an...  249.0
# 11                                           Robotics  249.0
# 12                           Animation and CGI Motion  249.0
# 13  Marketing Analytics: Price and Promotion Analy...  249.0
# 14                Basics of Computing and Programming  200.0
#
#            course_effort  n_enrolled  \
# 0    9–10 hours per week        6388
# 1     3–5 hours per week       16904
# 2   10–14 hours per week       85561
# 3    9–10 hours per week        7301
# 4    9–10 hours per week           0
# 5    8–10 hours per week       27241
# 6     5–7 hours per week       81140
# 7     5–7 hours per week       70682
# 8    8–10 hours per week      265104
# 9    8–10 hours per week      150855
# 10    5–7 hours per week       50588
# 11   8–10 hours per week       68199
# 12   8–10 hours per week       36827
# 13    5–7 hours per week       41021
# 14    6–8 hours per week       37045
#
#                                           institution
# 0                        Western Governors University
# 1                                   Boston University
# 2               Massachusetts Institute of Technology
# 3                        Western Governors University
# 4                        Western Governors University
# 5   University System of Maryland-University of Ma...
# 6                  University of California, Berkeley
# 7                  University of California, Berkeley
# 8                                 Columbia University
# 9                                 Columbia University
# 10                 University of California, Berkeley
# 11                                Columbia University
# 12                                Columbia University
# 13                 University of California, Berkeley
# 14                                New York University

# %%
sns.barplot(x = 'price', y = 'title', data = comp_sci_query, color = 'orange', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='title'>

# %%
sns.barplot(x = 'n_enrolled', y = 'title', data = comp_sci_query, color = 'orange', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='n_enrolled', ylabel='title'>

# %%
sns.barplot(x = 'price', y = 'n_enrolled', data = comp_sci_query, color = 'orange', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='n_enrolled'>

# %%
data_analysis_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_program_enrollment, COUNT(title) AS num_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                                    FROM edx_course_descriptions 
                                    WHERE subject == 'Data Analysis & Statistics'
                                    ORDER BY price DESC ''', edx_conn)
data_analysis_tot
# Out:
#    total_program_enrollment  num_courses  avg_course_purchase  \
# 0                   4264412           72             92.63875
#
#    min_course_purchase  max_course_purchase
# 0                 25.0                350.0

# %%
comp_sci_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_program_enrollment, COUNT(title) AS num_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                               FROM edx_course_descriptions
                               WHERE subject == 'Computer Science'
                               ORDER BY price DESC ''', edx_conn)
comp_sci_tot
# Out:
#    total_program_enrollment  num_courses  avg_course_purchase  \
# 0                  12447737          166           125.012048
#
#    min_course_purchase  max_course_purchase
# 0                 49.0                399.6

# %%
edx_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_edx_enrollment, COUNT(title) AS total_courses, AVG(price) AS total_avg
                          FROM edx_course_descriptions
                          ORDER BY price DESC ''', edx_conn)
edx_tot
# Out:
#    total_edx_enrollment  total_courses  total_avg
# 0              45530665           2706   36.12929

# %%
business_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_business_enrollment, COUNT(title) AS total_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase 
                               FROM edx_course_descriptions
                               WHERE subject == 'Business & Management'
                               ORDER BY price DESC ''', edx_conn)
business_tot
# Out:
#    total_business_enrollment  total_courses  avg_course_purchase  \
# 0                    7076563            164           132.542683
#
#    min_course_purchase  max_course_purchase
# 0                  5.0                399.0

# %%
engineering_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_engineering_enrollment, COUNT(title) AS total_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                               FROM edx_course_descriptions
                               WHERE subject == 'Engineering'
                               ORDER BY price DESC ''', edx_conn)
engineering_tot
# Out:
#    total_engineering_enrollment  total_courses  avg_course_purchase  \
# 0                       1396839             58           116.982759
#
#    min_course_purchase  max_course_purchase
# 0                 25.0                299.0

# %%
ed_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_education_enrollment, COUNT(title) AS total_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                               FROM edx_course_descriptions
                               WHERE subject == 'Education & Teacher Training'
                               ORDER BY price DESC ''', edx_conn)
ed_tot
# Out:
#    total_education_enrollment  total_courses  avg_course_purchase  \
# 0                      706532             29            83.068966
#
#    min_course_purchase  max_course_purchase
# 0                 25.0                299.0

# %%
law_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_law_enrollment, COUNT(title) AS total_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                               FROM edx_course_descriptions
                               WHERE subject == 'Law'
                               ORDER BY price DESC ''', edx_conn)
law_tot
# Out:
#    total_law_enrollment  total_courses  avg_course_purchase  \
# 0                291436             10                112.0
#
#    min_course_purchase  max_course_purchase
# 0                 25.0                199.0

# %%
econ_tot = pd.read_sql(''' SELECT SUM(n_enrolled) AS total_economics_enrollment, COUNT(title) AS total_courses, AVG(price) AS avg_course_purchase, MIN(price) AS min_course_purchase, MAX(price) AS max_course_purchase
                               FROM edx_course_descriptions
                               WHERE subject == 'Economics & Finance'
                               ORDER BY price DESC ''', edx_conn)
econ_tot
# Out:
#    total_economics_enrollment  total_courses  avg_course_purchase  \
# 0                      835907             46            75.649565
#
#    min_course_purchase  max_course_purchase
# 0                  5.0                450.0

# %%
by_subject = pd.read_sql(''' SELECT subject, COUNT(subject) AS subject_count,
                             100 * COUNT(subject) / (SELECT COUNT(*) FROM edx_course_descriptions) AS subject_pct
                             FROM edx_course_descriptions
                             GROUP BY subject
                             ORDER BY subject_pct DESC LIMIT 10''', edx_conn)
by_subject
# Out:
#                         subject  subject_count  subject_pct
# 0              Computer Science            166            6
# 1         Business & Management            164            6
# 2                    Humanities             64            2
# 3                   Engineering             58            2
# 4    Data Analysis & Statistics             72            2
# 5               Social Sciences             51            1
# 6                      Medicine             30            1
# 7                          Math             31            1
# 8                      Language             34            1
# 9  Education & Teacher Training             29            1

# %%
by_subject_csv = by_subject.to_csv('by_subject_csv.csv')

# %%
sns.barplot(x = 'subject_pct', y = 'subject', data = by_subject, color = 'red', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='subject_pct', ylabel='subject'>

# %%
edx_by_price = pd.read_sql(''' SELECT price, COUNT(price) AS price_count,
                           100 * COUNT(price) / (SELECT COUNT(*) FROM edx_course_descriptions) AS price_pct
                           FROM edx_course_descriptions
                           GROUP BY price
                           ORDER BY price_pct DESC LIMIT 10 ''', edx_conn)
edx_by_price
# Out:
#    price  price_count  price_pct
# 0    0.0         1733         64
# 1   49.0          269          9
# 2   99.0          137          5
# 3  199.0           85          3
# 4   50.0           96          3
# 5  149.0           78          2
# 6  150.0           30          1
# 7  139.0           32          1
# 8   25.0           49          1
# 9  450.0            1          0

# %%
edx_price_pct_csv = edx_by_price.to_csv('edx_price_pct.csv')

# %%
sns.barplot(x = 'price', y = 'price_pct', data =edx_by_price, color = 'red', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='price_pct'>

# %%
by_course_effort = pd.read_sql(''' SELECT course_effort, COUNT(course_effort) AS num_hours, 
                                   100 * COUNT(course_effort) / (SELECT COUNT(*) FROM edx_course_descriptions) AS hours_pct
                                   FROM edx_course_descriptions 
                                   GROUP BY course_effort
                                   ORDER BY hours_pct DESC LIMIT 10 ''', edx_conn)
by_course_effort
# Out:
#          course_effort  num_hours  hours_pct
# 0   3–5 hours per week        102          3
# 1   3–4 hours per week         91          3
# 2   2–4 hours per week        108          3
# 3   2–3 hours per week        104          3
# 4  8–10 hours per week         57          2
# 5   4–6 hours per week         79          2
# 6   4–5 hours per week         55          2
# 7   1–2 hours per week         55          2
# 8   6–8 hours per week         51          1
# 9   5–7 hours per week         28          1

# %%
sns.barplot(x = 'hours_pct', y = 'course_effort', data = by_course_effort, color = 'red', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='hours_pct', ylabel='course_effort'>

# %%
by_institution = pd.read_sql(''' SELECT institution, COUNT(institution) AS institution_count,
                                 100 * COUNT(institution) / (SELECT COUNT(*) FROM edx_course_descriptions) AS institution_pct
                                 FROM edx_course_descriptions
                                 GROUP BY institution
                                 ORDER BY institution_pct DESC LIMIT 10''', edx_conn)
by_institution
# Out:
#                                          institution  institution_count  \
# 0                                 Harvard University                104
# 1                Universitat Politècnica de Valencia                 47
# 2              Massachusetts Institute of Technology                 41
# 3                    Inter-American Development Bank                 29
# 4                                                IBM                 30
# 5                     Delft University of Technology                 30
# 6           École polytechnique fédérale de Lausanne                  6
# 7  https://www.edx.org/course/the-business-of-mining                  1
# 8  https://www.edx.org/course/strategic-social-me...                  1
# 9  https://www.edx.org/course/six-sigma-analyze-i...                  1
#
#    institution_pct
# 0                3
# 1                1
# 2                1
# 3                1
# 4                1
# 5                1
# 6                0
# 7                0
# 8                0
# 9                0

# %%
sns.barplot(x = 'institution_count', y = 'institution', data = by_institution, color = 'red', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='institution_count', ylabel='institution'>

# %%
by_institution_comp_sci = pd.read_sql(''' SELECT institution, COUNT(institution) AS institution_count,
                                 100 * COUNT(institution) / (SELECT COUNT(*) FROM edx_course_descriptions) AS institution_pct
                                 FROM edx_course_descriptions
                                 WHERe subject == 'Computer Science'
                                 GROUP BY institution
                                 ORDER BY institution_count DESC LIMIT 10''', edx_conn)
by_institution_comp_sci
# Out:
#                             institution  institution_count  institution_pct
# 0   Universitat Politècnica de Valencia                 13                0
# 1                                   IBM                 10                0
# 2    University of California, Berkeley                  8                0
# 3                  The Linux Foundation                  8                0
# 4                   Stanford University                  8                0
# 5                    Harvard University                  8                0
# 6                   Columbia University                  7                0
# 7                   Amazon Web Services                  7                0
# 8  Dartmouth_IMTx-Dartmouth College-IMT                  6                0
# 9                     Curtin University                  6                0

# %%
sns.barplot(x = 'institution_count', y = 'institution', data = by_institution_comp_sci, color = 'red', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='institution_count', ylabel='institution'>

# %%
subject_hundred = pd.read_sql(''' SELECT subject, AVG(price) as avg_price_subject
                                  FROM edx_course_descriptions
                                  WHERE price > 100.0 
                                  GROUP BY subject
                                  ORDER BY avg_price_subject DESC LIMIT 10''', edx_conn)
subject_hundred = subject_hundred.round(2)
subject_hundred
# Out:
#                         subject  avg_price_subject
# 0  Education & Teacher Training             227.00
# 1    Data Analysis & Statistics             222.38
# 2           Economics & Finance             213.56
# 3                     Chemistry             199.00
# 4                 Art & Culture             196.50
# 5                   Engineering             192.96
# 6              Computer Science             189.61
# 7         Environmental Studies             189.00
# 8                        Design             189.00
# 9         Business & Management             183.19

# %%
sns.barplot(x = 'avg_price_subject', y = 'subject', data = subject_hundred, color = 'purple', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='avg_price_subject', ylabel='subject'>

# %%
by_enroll = pd.read_sql(''' SELECT subject, SUM(n_enrolled) AS total_enrollment
                          FROM edx_course_descriptions 
                          GROUP BY subject
                          ORDER BY total_enrollment DESC LIMIT 10 ''', edx_conn)
by_enroll
# Out:
#                       subject  total_enrollment
# 0            Computer Science          12447737
# 1       Business & Management           7076563
# 2               Communication           4641327
# 3  Data Analysis & Statistics           4264412
# 4                  Humanities           3504140
# 5             Social Sciences           1844379
# 6     Biology & Life Sciences           1763832
# 7                 Engineering           1396839
# 8                    Language           1063257
# 9                    Medicine            982827

# %%
by_enroll_csv = by_enroll.to_csv('by_enroll.csv')

# %%
sns.barplot(x = 'total_enrollment', y = 'subject', data = by_enroll, color = 'purple', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='total_enrollment', ylabel='subject'>

# %%
by_avg_enroll = pd.read_sql(''' SELECT subject, AVG(n_enrolled) AS avg_enrollment
                          FROM edx_course_descriptions 
                          GROUP BY subject
                          ORDER BY avg_enrollment DESC LIMIT 10 ''', edx_conn)
by_avg_enroll
# Out:
#                       subject  avg_enrollment
# 0               Communication   119008.384615
# 1                Architecture    91322.200000
# 2            Computer Science    74986.367470
# 3  Data Analysis & Statistics    59227.944444
# 4                  Humanities    54752.187500
# 5     Biology & Life Sciences    50395.200000
# 6                  Literature    47898.000000
# 7       Business & Management    43149.774390
# 8                   Chemistry    39507.000000
# 9             Social Sciences    36164.294118

# %%
sns.barplot(x = 'avg_enrollment', y = 'subject', data = by_avg_enroll, color = 'purple', edgecolor='black', ci=False)
# Out:
# <AxesSubplot:xlabel='avg_enrollment', ylabel='subject'>

# %%
Path('edx_behavior.db').touch()
edx_behavior_conn = sqlite3.connect('edx_behavior.db')
edx_behavior_cursor = edx_conn.cursor()

# %%
edx_user_data.to_sql('edx_behavior', edx_behavior_conn, if_exists='append', index=False)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
edx_user_data_init_query = pd.read_sql(''' SELECT * FROM edx_behavior LIMIT 5 ''', edx_behavior_conn)
edx_user_data_init_query
# Out:
#    Unnamed: 0 institute course_id  year semester       userid_DI  viewed  \
# 0           4  HarvardX    PH207x  2012     Fall  MHxPC130313697       0
# 1           6  HarvardX    PH207x  2012     Fall  MHxPC130237753       1
# 2           7  HarvardX     CS50x  2012   Summer  MHxPC130202970       1
# 3          20  HarvardX     CS50x  2012   Summer  MHxPC130223941       1
# 4          22  HarvardX    PH207x  2012     Fall  MHxPC130317399       0
#
#    explored  certified               final_cc_cname_DI  ... grade  \
# 0         0          0                           India  ...   0.0
# 1         0          0                   United States  ...   0.0
# 2         0          0                   United States  ...   0.0
# 3         0          0  Other Middle East/Central Asia  ...   0.0
# 4         0          0                       Australia  ...   0.0
#
#   start_time_DI  last_event_DI nevents ndays_act  nplay_video  nchapters  \
# 0    2012-07-24     2013-07-27       6         3       197757          0
# 1    2012-07-24     2012-12-24     107         8            7          2
# 2    2012-07-24     2013-03-28       8         1       197757          1
# 3    2012-07-24     2013-07-15      25         2       197757          4
# 4    2012-07-24     2012-08-25       3         2       197757          0
#
#    nforum_posts  incomplete_flag  age
# 0             0                0   23
# 1             0                0   19
# 2             0                0   24
# 3             0                0   20
# 4             0                0   32
#
# [5 rows x 22 columns]

# %%
udemy = pd.read_csv('udemy_courses.csv')
udemy
# Out:
#      udemy_courses                                         Unnamed: 1  \
# 0        course_id                                       course_title
# 1          1070968                 Ultimate Investment Banking Course
# 2          1113822  Complete GST Course & Certification - Grow You...
# 3          1006314  Financial Modeling for Business Analysts and C...
# 4          1210588  Beginner to Pro - Financial Analysis in Excel ...
# ...            ...                                                ...
# 3674        775618  Learn jQuery from Scratch - Master of JavaScri...
# 3675       1088178  How To Design A WordPress Website With No Codi...
# 3676        635248                      Learn and Build using Polymer
# 3677        905096  CSS Animations: Create Amazing Effects on Your...
# 3678        297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                              Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                   url    is_paid      price
# 1     https://www.udemy.com/ultimate-investment-bank...       TRUE        200
# 2         https://www.udemy.com/goods-and-services-tax/       TRUE         75
# 3     https://www.udemy.com/financial-modeling-for-b...       TRUE         45
# 4     https://www.udemy.com/complete-excel-finance-c...       TRUE         95
# ...                                                 ...        ...        ...
# 3674  https://www.udemy.com/easy-jquery-for-beginner...       TRUE        100
# 3675  https://www.udemy.com/how-to-make-a-wordpress-...       TRUE         25
# 3676  https://www.udemy.com/learn-and-build-using-po...       TRUE         40
# 3677  https://www.udemy.com/css-animations-create-am...       TRUE         50
# 3678  https://www.udemy.com/using-modx-cms-to-build-...       TRUE         45
#
#            Unnamed: 5   Unnamed: 6    Unnamed: 7          Unnamed: 8  \
# 0     num_subscribers  num_reviews  num_lectures               level
# 1                2147           23            51          All Levels
# 2                2792          923           274          All Levels
# 3                2174           74            51  Intermediate Level
# 4                2451           11            36          All Levels
# ...               ...          ...           ...                 ...
# 3674             1040           14            21          All Levels
# 3675              306            3            42      Beginner Level
# 3676              513          169            48          All Levels
# 3677              300           31            38          All Levels
# 3678              901           36            20      Beginner Level
#
#             Unnamed: 9           Unnamed: 10       Unnamed: 11
# 0     content_duration   published_timestamp           subject
# 1                  1.5  2017-01-18T20:58:58Z  Business Finance
# 2                   39  2017-03-09T16:34:20Z  Business Finance
# 3                  2.5  2016-12-19T19:26:30Z  Business Finance
# 4                    3  2017-05-30T20:07:24Z  Business Finance
# ...                ...                   ...               ...
# 3674                 2  2016-06-14T17:36:46Z   Web Development
# 3675               3.5  2017-03-10T22:24:30Z   Web Development
# 3676               3.5  2015-12-30T16:41:42Z   Web Development
# 3677                 3  2016-08-11T19:06:15Z   Web Development
# 3678                 2  2014-09-28T19:51:11Z   Web Development
#
# [3679 rows x 12 columns]
